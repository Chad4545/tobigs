# %% [markdown]
# ## 1. 음이 아닌 정수로 이루어진 수열 A1, A2, ... An이 있다.
#
# ## 단조수열 B1, B2, ...,Bn을 만들어서 |A1-B1| + |A2-B2| + ...|An-Bn|의 값을
#
# ## 최소로 하는 프로그램을 작성하시오.|

# %%
# 수엶 A를 만든다 
A = input('수열 A : ')
A =[int(i) for i in A.split()]
A

# %%
# B를 만들어보자. 먼저 B의 값을 담을 빈리스트 생성
# 또한 B를 만들때, 단조수열의 법칙을 확인하기 위한 
B = []

for idx, num in enumerate(A):
    # B의 첫번째 숫자는 A의 최소값으로 시작해보자
    if idx == 0:
        B.append(min(A))
    
    elif

# %%
B = sorted(A)
B

# %% [markdown]
# ## 2.
#
# ## 원숭이가 바오밥나무를 타고 있습니다. 이 원숭이는 1시간당 나무를 30m 오른 후 50%확률로 15m 미끄러집니다.
#
# ## 입력값으로 n(5≤n)을 주었을 때, 원숭이가 150m의 나무의 꼭대기에 도달했을 때
#
# ## 걸리는 시간이 n일 확률을 출력하는 프로그램을 작성하시오.
#
# ## (단, 정상에 도달했더라도 미끄러진다면 다시 올라야하며, 135m지점에서 오르기 시작할 때에는 미끄러지더라도 150m에 도달하므로 상관이 없다.)
#
# - 입력 : 6
#
# - 출력 : 13.89%

# %% [markdown]
# ### 3. 반복 스펠링은 단어 내의 모든 문자에 대해, 스펠링이 1회 이상 연속해서 나타나는 경우를 말하는데, cccaaattb는 c,a,t,b,가 반복하기에 반복단어 스펠링이다.
#
# ### Pen도 p,e,n이 1회 연속하기에 반복 스펠링 단어이지만, alpha는 l,p,는 연속하지만 a가 연속하지 않기에 반복 스펠링 단어가 아니다.
#
# ### 단어로 이루어진 txt파일을 읽어와 반복 스펠링 단어의 개수를 출력하는 프로그램을 작성하시오 (첨부 txt파일 확인)
#
# - 입력 : alpha, beta, gamma, delta, epsilon, zeta, eta
#
# - 출력 : 5

# %%
import pandas as pd
data = pd.read_csv('a_dic.txt',sep=' ', header=None)
data.columns = ["word"]


#단어단위로 iterate
for word in data['word']:
    
    # 각 단어를 dict으로 만듦
    # alpha -> {'a':2,'l':1,'p':1,'h':1}
    check_dict = {}
    for char in word:
        check_dict[char] = check_dict.get(char,0) +1
    
    # 단어의 길이와 check_dict의 길이가 같다면
    # 유니크한 char조합의 단어라는 뜻이므로 반복스펠링단어
    if len(check_dict.keys()) == len(word):
        count += 1
        print('----')
        print('check_word: ', word)
        print(word,': repeat spelling word ')
    
    # 그 외는 char가 하나이상인 경우가 있으므로, 그 char가 연속인지 체크
    else:
        # 2개 이상 char를 담을 리스트 
        check_char=[]
        for key, val in check_dict.items():
            if val > 1:
                check_char.append(key)
        print('----')
        print('check_word: ', word)
        print('check_char_in_word: ', check_char)
        
        # check해야할 char를 얻었다.
        # word의 index를 활용하여 체크하자
        
        second_count = len(check_char)
        #print('len of secound_count: ',second_count)
        
        for char_in_check in check_char:
            #print('char_in_check: ', char_in_check)
            # alpha의 경우 a의 인덱스가 담긴 리스트 [0,4]
            # banana의 경우 a의 인덱스가 담긴 리스트 [1,3,5]
            last_check_list=[idx for idx, char in enumerate(word) if char == char_in_check]

            #print('last_check_list',last_check_list)
            if max(last_check_list) - min(last_check_list) == len(last_check_list) - 1:
                second_count -= 1
           
        if second_count == 0:
            count += 1
            print(word,': repeat spelling word ')
        else:
            print(word,': not repeat spelling word')
                
print(count)
# Out:
# ----
# check_word:  antirust
# check_char_in_word:  ['t']
# antirust : not repeat spelling word
# ----
# check_word:  antedate
# check_char_in_word:  ['a', 't', 'e']
# antedate : not repeat spelling word
# ----
# check_word:  adsorptive
# adsorptive : repeat spelling word
# ----
# check_word:  antidotal
# check_char_in_word:  ['a', 't']
# antidotal : not repeat spelling word
# ----
# check_word:  abdominal
# check_char_in_word:  ['a']
# abdominal : not repeat spelling word
# ----
# check_word:  assess
# check_char_in_word:  ['s']
# assess : not repeat spelling word
# ----
# check_word:  Achromycin
# check_char_in_word:  ['c']
# Achromycin : not repeat spelling word
# ----
# check_word:  atom
# atom : repeat spelling word
# ----
# check_word:  America
# America : repeat spelling word
# ----
# check_word:  altarrail
# check_char_in_word:  ['a', 'l', 'r']
# altarrail : not repeat spelling word
# ----
# check_word:  acryl
# acryl : repeat spelling word
# ----
# check_word:  Aegean
# check_char_in_word:  ['e']
# Aegean : not repeat spelling word
# ----
# check_word:  analytical
# check_char_in_word:  ['a', 'l']
# analytical : not repeat spelling word
# ----
# check_word:  absolve
# absolve : repeat spelling word
# ----
# check_word:  afterwar
# check_char_in_word:  ['a', 'r']
# afterwar : not repeat spelling word
# ----
# check_word:  acrimonious
# check_char_in_word:  ['i', 'o']
# acrimonious : not repeat spelling word
# ----
# check_word:  antagonist
# check_char_in_word:  ['a', 'n', 't']
# antagonist : not repeat spelling word
# ----
# check_word:  athwartship
# check_char_in_word:  ['a', 't', 'h']
# athwartship : not repeat spelling word
# ----
# check_word:  agential
# check_char_in_word:  ['a']
# agential : not repeat spelling word
# ----
# check_word:  aril
# aril : repeat spelling word
# ----
# check_word:  advice
# advice : repeat spelling word
# ----
# check_word:  AngloNorman
# check_char_in_word:  ['n', 'o']
# AngloNorman : not repeat spelling word
# ----
# check_word:  Alison
# Alison : repeat spelling word
# ----
# check_word:  assist
# check_char_in_word:  ['s']
# assist : not repeat spelling word
# ----
# check_word:  archaeopteryx
# check_char_in_word:  ['a', 'r', 'e']
# archaeopteryx : not repeat spelling word
# ----
# check_word:  asphaltite
# check_char_in_word:  ['a', 't']
# asphaltite : not repeat spelling word
# ----
# check_word:  atomization
# check_char_in_word:  ['a', 't', 'o', 'i']
# atomization : not repeat spelling word
# ----
# check_word:  afferent
# check_char_in_word:  ['f', 'e']
# afferent : not repeat spelling word
# ----
# check_word:  agrimony
# agrimony : repeat spelling word
# ----
# check_word:  audiphone
# audiphone : repeat spelling word
# ----
# check_word:  auditorium
# check_char_in_word:  ['u', 'i']
# auditorium : not repeat spelling word
# ----
# check_word:  afloat
# check_char_in_word:  ['a']
# afloat : not repeat spelling word
# ----
# check_word:  Alexander
# check_char_in_word:  ['e']
# Alexander : not repeat spelling word
# ----
# check_word:  anastigmat
# check_char_in_word:  ['a', 't']
# anastigmat : not repeat spelling word
# ----
# check_word:  appointment
# check_char_in_word:  ['p', 'n', 't']
# appointment : not repeat spelling word
# ----
# check_word:  amply
# amply : repeat spelling word
# ----
# check_word:  airborne
# check_char_in_word:  ['r']
# airborne : not repeat spelling word
# ----
# check_word:  Antiphlogistine
# check_char_in_word:  ['n', 't', 'i']
# Antiphlogistine : not repeat spelling word
# ----
# check_word:  archenemy
# check_char_in_word:  ['e']
# archenemy : not repeat spelling word
# ----
# check_word:  arclamp
# check_char_in_word:  ['a']
# arclamp : not repeat spelling word
# ----
# check_word:  Arnaut
# Arnaut : repeat spelling word
# ----
# check_word:  ator
# ator : repeat spelling word
# ----
# check_word:  anile
# anile : repeat spelling word
# ----
# check_word:  augend
# augend : repeat spelling word
# ----
# check_word:  Amos
# Amos : repeat spelling word
# ----
# check_word:  analogism
# check_char_in_word:  ['a']
# analogism : not repeat spelling word
# ----
# check_word:  adlibitum
# check_char_in_word:  ['i']
# adlibitum : not repeat spelling word
# ----
# check_word:  acotyledon
# check_char_in_word:  ['o']
# acotyledon : not repeat spelling word
# ----
# check_word:  arioso
# check_char_in_word:  ['o']
# arioso : not repeat spelling word
# ----
# check_word:  allow
# check_char_in_word:  ['l']
# allow : repeat spelling word
# ----
# check_word:  anneal
# check_char_in_word:  ['a', 'n']
# anneal : not repeat spelling word
# ----
# check_word:  actualite
# check_char_in_word:  ['a', 't']
# actualite : not repeat spelling word
# ----
# check_word:  alienism
# check_char_in_word:  ['i']
# alienism : not repeat spelling word
# ----
# check_word:  Aries
# Aries : repeat spelling word
# ----
# check_word:  androgyny
# check_char_in_word:  ['n', 'y']
# androgyny : not repeat spelling word
# ----
# check_word:  Asgarde
# Asgarde : repeat spelling word
# ----
# check_word:  accessary
# check_char_in_word:  ['a', 'c', 's']
# accessary : not repeat spelling word
# ----
# check_word:  ablush
# ablush : repeat spelling word
# ----
# check_word:  auditorial
# check_char_in_word:  ['a', 'i']
# auditorial : not repeat spelling word
# ----
# check_word:  admeasure
# check_char_in_word:  ['a', 'e']
# admeasure : not repeat spelling word
# ----
# check_word:  analogic
# check_char_in_word:  ['a']
# analogic : not repeat spelling word
# ----
# check_word:  alunite
# alunite : repeat spelling word
# ----
# check_word:  appal
# check_char_in_word:  ['a', 'p']
# appal : not repeat spelling word
# ----
# check_word:  agglutinin
# check_char_in_word:  ['g', 'i', 'n']
# agglutinin : not repeat spelling word
# ----
# check_word:  amphibrach
# check_char_in_word:  ['a', 'h']
# amphibrach : not repeat spelling word
# ----
# check_word:  aiming
# check_char_in_word:  ['i']
# aiming : not repeat spelling word
# ----
# check_word:  arsphenamine
# check_char_in_word:  ['a', 'e', 'n']
# arsphenamine : not repeat spelling word
# ----
# check_word:  assize
# check_char_in_word:  ['s']
# assize : repeat spelling word
# ----
# check_word:  armourred
# check_char_in_word:  ['r']
# armourred : not repeat spelling word
# ----
# check_word:  accordance
# check_char_in_word:  ['a', 'c']
# accordance : not repeat spelling word
# ----
# check_word:  alpaca
# check_char_in_word:  ['a']
# alpaca : not repeat spelling word
# ----
# check_word:  arabian
# check_char_in_word:  ['a']
# arabian : not repeat spelling word
# ----
# check_word:  anapestic
# check_char_in_word:  ['a']
# anapestic : not repeat spelling word
# ----
# check_word:  ack.
# ack. : repeat spelling word
# ----
# check_word:  architrave
# check_char_in_word:  ['a', 'r']
# architrave : not repeat spelling word
# ----
# check_word:  antiphrasis
# check_char_in_word:  ['a', 'i', 's']
# antiphrasis : not repeat spelling word
# ----
# check_word:  apocalyptic
# check_char_in_word:  ['a', 'p', 'c']
# apocalyptic : not repeat spelling word
# ----
# check_word:  afters
# afters : repeat spelling word
# ----
# check_word:  aggravate
# check_char_in_word:  ['a', 'g']
# aggravate : not repeat spelling word
# ----
# check_word:  aliyah
# check_char_in_word:  ['a']
# aliyah : not repeat spelling word
# ----
# check_word:  anthropometry
# check_char_in_word:  ['t', 'r', 'o']
# anthropometry : not repeat spelling word
# ----
# check_word:  abstention
# check_char_in_word:  ['t', 'n']
# abstention : not repeat spelling word
# ----
# check_word:  artificer
# check_char_in_word:  ['r', 'i']
# artificer : not repeat spelling word
# ----
# check_word:  aeromedicine
# check_char_in_word:  ['e', 'i']
# aeromedicine : not repeat spelling word
# ----
# check_word:  apostrophize
# check_char_in_word:  ['p', 'o']
# apostrophize : not repeat spelling word
# ----
# check_word:  artillery
# check_char_in_word:  ['r', 'l']
# artillery : not repeat spelling word
# ----
# check_word:  abrogative
# check_char_in_word:  ['a']
# abrogative : not repeat spelling word
# ----
# check_word:  antinuke
# check_char_in_word:  ['n']
# antinuke : not repeat spelling word
# ----
# check_word:  agonist
# agonist : repeat spelling word
# ----
# check_word:  accepter
# check_char_in_word:  ['c', 'e']
# accepter : not repeat spelling word
# ----
# check_word:  analyzability
# check_char_in_word:  ['a', 'l', 'y', 'i']
# analyzability : not repeat spelling word
# ----
# check_word:  algal
# check_char_in_word:  ['a', 'l']
# algal : not repeat spelling word
# ----
# check_word:  accountable
# check_char_in_word:  ['a', 'c']
# accountable : not repeat spelling word
# ----
# check_word:  ademption
# ademption : repeat spelling word
# ----
# check_word:  adhere
# check_char_in_word:  ['e']
# adhere : not repeat spelling word
# ----
# check_word:  antigropelos
# check_char_in_word:  ['o']
# antigropelos : not repeat spelling word
# ----
# check_word:  althaea
# check_char_in_word:  ['a']
# althaea : not repeat spelling word
# ----
# check_word:  airfare
# check_char_in_word:  ['a', 'r']
# airfare : not repeat spelling word
# ----
# check_word:  absolutist
# check_char_in_word:  ['s', 't']
# absolutist : not repeat spelling word
# ----
# check_word:  abstrusity
# check_char_in_word:  ['s', 't']
# abstrusity : not repeat spelling word
# ----
# check_word:  accuse
# check_char_in_word:  ['c']
# accuse : repeat spelling word
# ----
# check_word:  aetatis
# check_char_in_word:  ['a', 't']
# aetatis : not repeat spelling word
# ----
# check_word:  apprehesive
# check_char_in_word:  ['p', 'e']
# apprehesive : not repeat spelling word
# ----
# check_word:  Adonis
# Adonis : repeat spelling word
# ----
# check_word:  acarpous
# check_char_in_word:  ['a']
# acarpous : not repeat spelling word
# ----
# check_word:  acceleration
# check_char_in_word:  ['a', 'c', 'e']
# acceleration : not repeat spelling word
# ----
# check_word:  adown
# adown : repeat spelling word
# ----
# check_word:  arbitration
# check_char_in_word:  ['a', 'r', 'i', 't']
# arbitration : not repeat spelling word
# ----
# check_word:  apprentice
# check_char_in_word:  ['p', 'e']
# apprentice : not repeat spelling word
# ----
# check_word:  angelica
# check_char_in_word:  ['a']
# angelica : not repeat spelling word
# ----
# check_word:  aboriginal
# check_char_in_word:  ['a', 'i']
# aboriginal : not repeat spelling word
# ----
# check_word:  acred
# acred : repeat spelling word
# ----
# check_word:  adsorption
# check_char_in_word:  ['o']
# adsorption : not repeat spelling word
# ----
# check_word:  animato
# check_char_in_word:  ['a']
# animato : not repeat spelling word
# ----
# check_word:  adynamia
# check_char_in_word:  ['a']
# adynamia : not repeat spelling word
# ----
# check_word:  arguable
# check_char_in_word:  ['a']
# arguable : not repeat spelling word
# ----
# check_word:  argue
# argue : repeat spelling word
# ----
# check_word:  angioma
# check_char_in_word:  ['a']
# angioma : not repeat spelling word
# ----
# check_word:  antiair
# check_char_in_word:  ['a', 'i']
# antiair : not repeat spelling word
# ----
# check_word:  asquint
# asquint : repeat spelling word
# ----
# check_word:  audial
# check_char_in_word:  ['a']
# audial : not repeat spelling word
# ----
# check_word:  acton
# acton : repeat spelling word
# ----
# check_word:  anymore
# anymore : repeat spelling word
# ----
# check_word:  annoy
# check_char_in_word:  ['n']
# annoy : repeat spelling word
# ----
# check_word:  applause
# check_char_in_word:  ['a', 'p']
# applause : not repeat spelling word
# ----
# check_word:  amnestic
# amnestic : repeat spelling word
# ----
# check_word:  alcoholicity
# check_char_in_word:  ['l', 'c', 'o', 'i']
# alcoholicity : not repeat spelling word
# ----
# check_word:  Amtrak
# Amtrak : repeat spelling word
# ----
# check_word:  abeyance
# check_char_in_word:  ['a', 'e']
# abeyance : not repeat spelling word
# ----
# check_word:  acquittal
# check_char_in_word:  ['a', 't']
# acquittal : not repeat spelling word
# ----
# check_word:  anagrammatic
# check_char_in_word:  ['a', 'm']
# anagrammatic : not repeat spelling word
# ----
# check_word:  academicism
# check_char_in_word:  ['a', 'c', 'm', 'i']
# academicism : not repeat spelling word
# ----
# check_word:  ambo
# ambo : repeat spelling word
# ----
# check_word:  academe
# check_char_in_word:  ['a', 'e']
# academe : not repeat spelling word
# ----
# check_word:  antismog
# antismog : repeat spelling word
# ----
# check_word:  aqualung
# check_char_in_word:  ['a', 'u']
# aqualung : not repeat spelling word
# ----
# check_word:  anamnesis
# check_char_in_word:  ['a', 'n', 's']
# anamnesis : not repeat spelling word
# ----
# check_word:  adjuration
# check_char_in_word:  ['a']
# adjuration : not repeat spelling word
# ----
# check_word:  Ashanti
# Ashanti : repeat spelling word
# ----
# check_word:  allweather
# check_char_in_word:  ['a', 'l', 'e']
# allweather : not repeat spelling word
# ----
# check_word:  arching
# arching : repeat spelling word
# ----
# check_word:  adversely
# check_char_in_word:  ['e']
# adversely : not repeat spelling word
# ----
# check_word:  auding
# auding : repeat spelling word
# ----
# check_word:  anthracitous
# check_char_in_word:  ['a', 't']
# anthracitous : not repeat spelling word
# ----
# check_word:  alder
# alder : repeat spelling word
# ----
# check_word:  antidumping
# check_char_in_word:  ['n', 'i']
# antidumping : not repeat spelling word
# ----
# check_word:  armourbearer
# check_char_in_word:  ['a', 'r', 'e']
# armourbearer : not repeat spelling word
# ----
# check_word:  artifact
# check_char_in_word:  ['a', 't']
# artifact : not repeat spelling word
# ----
# check_word:  agena
# check_char_in_word:  ['a']
# agena : not repeat spelling word
# ----
# check_word:  almswoman
# check_char_in_word:  ['a', 'm']
# almswoman : not repeat spelling word
# ----
# check_word:  androecium
# androecium : repeat spelling word
# ----
# check_word:  adumbrate
# check_char_in_word:  ['a']
# adumbrate : not repeat spelling word
# ----
# check_word:  appointee
# check_char_in_word:  ['p', 'e']
# appointee : repeat spelling word
# ----
# check_word:  antemundane
# check_char_in_word:  ['a', 'n', 'e']
# antemundane : not repeat spelling word
# ----
# check_word:  argot
# argot : repeat spelling word
# ----
# check_word:  associated
# check_char_in_word:  ['a', 's']
# associated : not repeat spelling word
# ----
# check_word:  ackemma
# check_char_in_word:  ['a', 'm']
# ackemma : not repeat spelling word
# ----
# check_word:  almandine
# check_char_in_word:  ['a', 'n']
# almandine : not repeat spelling word
# ----
# check_word:  adenosine
# check_char_in_word:  ['e', 'n']
# adenosine : not repeat spelling word
# ----
# check_word:  anaglyph
# check_char_in_word:  ['a']
# anaglyph : not repeat spelling word
# ----
# check_word:  answering
# check_char_in_word:  ['n']
# answering : not repeat spelling word
# ----
# check_word:  admirer
# check_char_in_word:  ['r']
# admirer : not repeat spelling word
# ----
# check_word:  aperidoic
# check_char_in_word:  ['i']
# aperidoic : not repeat spelling word
# ----
# check_word:  abstersion
# check_char_in_word:  ['s']
# abstersion : not repeat spelling word
# ----
# check_word:  anechoic
# check_char_in_word:  ['c']
# anechoic : not repeat spelling word
# ----
# check_word:  army
# army : repeat spelling word
# ----
# check_word:  addicted
# check_char_in_word:  ['d']
# addicted : not repeat spelling word
# ----
# check_word:  Abomb
# check_char_in_word:  ['b']
# Abomb : not repeat spelling word
# ----
# check_word:  antiicer
# check_char_in_word:  ['i']
# antiicer : repeat spelling word
# ----
# check_word:  anastrophe
# check_char_in_word:  ['a']
# anastrophe : not repeat spelling word
# ----
# check_word:  afterdamp
# check_char_in_word:  ['a']
# afterdamp : not repeat spelling word
# ----
# check_word:  allwhite
# check_char_in_word:  ['l']
# allwhite : repeat spelling word
# ----
# check_word:  alcometer
# check_char_in_word:  ['e']
# alcometer : not repeat spelling word
# ----
# check_word:  antennule
# check_char_in_word:  ['n', 'e']
# antennule : not repeat spelling word
# ----
# check_word:  agnate
# check_char_in_word:  ['a']
# agnate : not repeat spelling word
# ----
# check_word:  admire
# admire : repeat spelling word
# ----
# check_word:  abrasion
# check_char_in_word:  ['a']
# abrasion : not repeat spelling word
# ----
# check_word:  afterworld
# check_char_in_word:  ['r']
# afterworld : not repeat spelling word
# ----
# check_word:  antimonsoon
# check_char_in_word:  ['n', 'o']
# antimonsoon : not repeat spelling word
# ----
# check_word:  angled
# angled : repeat spelling word
# ----
# check_word:  archpriest
# check_char_in_word:  ['r']
# archpriest : not repeat spelling word
# ----
# check_word:  argentous
# argentous : repeat spelling word
# ----
# check_word:  assegai
# check_char_in_word:  ['a', 's']
# assegai : not repeat spelling word
# ----
# check_word:  assai
# check_char_in_word:  ['a', 's']
# assai : not repeat spelling word
# ----
# check_word:  alary
# check_char_in_word:  ['a']
# alary : not repeat spelling word
# ----
# check_word:  anticipative
# check_char_in_word:  ['a', 't', 'i']
# anticipative : not repeat spelling word
# ----
# check_word:  attainder
# check_char_in_word:  ['a', 't']
# attainder : not repeat spelling word
# ----
# check_word:  antechoir
# antechoir : repeat spelling word
# ----
# check_word:  anthropological
# check_char_in_word:  ['a', 'o', 'l']
# anthropological : not repeat spelling word
# ----
# check_word:  ascensive
# check_char_in_word:  ['s', 'e']
# ascensive : not repeat spelling word
# ----
# check_word:  alterative
# check_char_in_word:  ['a', 't', 'e']
# alterative : not repeat spelling word
# ----
# check_word:  anklebone
# check_char_in_word:  ['n', 'e']
# anklebone : not repeat spelling word
# ----
# check_word:  adoptive
# adoptive : repeat spelling word
# ----
# check_word:  acatalepsy
# check_char_in_word:  ['a']
# acatalepsy : not repeat spelling word
# ----
# check_word:  airbreathe
# check_char_in_word:  ['a', 'r', 'e']
# airbreathe : not repeat spelling word
# ----
# check_word:  alkalize
# check_char_in_word:  ['a', 'l']
# alkalize : not repeat spelling word
# ----
# check_word:  acidulate
# check_char_in_word:  ['a']
# acidulate : not repeat spelling word
# ----
# check_word:  artificially
# check_char_in_word:  ['a', 'i', 'l']
# artificially : not repeat spelling word
# ----
# check_word:  agaric
# check_char_in_word:  ['a']
# agaric : not repeat spelling word
# ----
# check_word:  apache
# check_char_in_word:  ['a']
# apache : not repeat spelling word
# ----
# check_word:  abolition
# check_char_in_word:  ['o', 'i']
# abolition : not repeat spelling word
# ----
# check_word:  alburnum
# check_char_in_word:  ['u']
# alburnum : not repeat spelling word
# ----
# check_word:  abatis
# check_char_in_word:  ['a']
# abatis : not repeat spelling word
# ----
# check_word:  aggradation
# check_char_in_word:  ['a', 'g']
# aggradation : not repeat spelling word
# ----
# check_word:  anthropophagi
# check_char_in_word:  ['a', 'h', 'o', 'p']
# anthropophagi : not repeat spelling word
# ----
# check_word:  attic
# check_char_in_word:  ['t']
# attic : repeat spelling word
# ----
# check_word:  attornment
# check_char_in_word:  ['t', 'n']
# attornment : not repeat spelling word
# ----
# check_word:  allpowerful
# check_char_in_word:  ['l']
# allpowerful : not repeat spelling word
# ----
# check_word:  agamy
# check_char_in_word:  ['a']
# agamy : not repeat spelling word
# ----
# check_word:  artichoke
# artichoke : repeat spelling word
# ----
# check_word:  Acheron
# Acheron : repeat spelling word
# ----
# check_word:  acupuncture
# check_char_in_word:  ['c', 'u']
# acupuncture : not repeat spelling word
# ----
# check_word:  advised
# check_char_in_word:  ['d']
# advised : not repeat spelling word
# ----
# check_word:  aeroplankton
# check_char_in_word:  ['a', 'o', 'n']
# aeroplankton : not repeat spelling word
# ----
# check_word:  anesthetization
# check_char_in_word:  ['a', 'n', 'e', 't', 'i']
# anesthetization : not repeat spelling word
# ----
# check_word:  aphis
# aphis : repeat spelling word
# ----
# check_word:  atmospherics
# check_char_in_word:  ['s']
# atmospherics : not repeat spelling word
# ----
# check_word:  Amish
# Amish : repeat spelling word
# ----
# check_word:  ases
# check_char_in_word:  ['s']
# ases : not repeat spelling word
# ----
# check_word:  arduous
# check_char_in_word:  ['u']
# arduous : not repeat spelling word
# ----
# check_word:  afflictive
# check_char_in_word:  ['f', 'i']
# afflictive : not repeat spelling word
# ----
# check_word:  atavism
# check_char_in_word:  ['a']
# atavism : not repeat spelling word
# ----
# check_word:  anathema
# check_char_in_word:  ['a']
# anathema : not repeat spelling word
# ----
# check_word:  accurate
# check_char_in_word:  ['a', 'c']
# accurate : not repeat spelling word
# ----
# check_word:  annoyance
# check_char_in_word:  ['a', 'n']
# annoyance : not repeat spelling word
# ----
# check_word:  aborning
# check_char_in_word:  ['n']
# aborning : not repeat spelling word
# ----
# check_word:  absentee
# check_char_in_word:  ['e']
# absentee : not repeat spelling word
# ----
# check_word:  adenectomy
# check_char_in_word:  ['e']
# adenectomy : not repeat spelling word
# ----
# check_word:  apronful
# apronful : repeat spelling word
# ----
# check_word:  argental
# check_char_in_word:  ['a']
# argental : not repeat spelling word
# ----
# check_word:  accost
# check_char_in_word:  ['c']
# accost : repeat spelling word
# ----
# check_word:  agaze
# check_char_in_word:  ['a']
# agaze : not repeat spelling word
# ----
# check_word:  amazed
# check_char_in_word:  ['a']
# amazed : not repeat spelling word
# ----
# check_word:  arise
# arise : repeat spelling word
# ----
# check_word:  agrimotor
# check_char_in_word:  ['r', 'o']
# agrimotor : not repeat spelling word
# ----
# check_word:  airfoil
# check_char_in_word:  ['i']
# airfoil : not repeat spelling word
# ----
# check_word:  armoire
# check_char_in_word:  ['r']
# armoire : not repeat spelling word
# ----
# check_word:  Anjou
# Anjou : repeat spelling word
# ----
# check_word:  acolyte
# acolyte : repeat spelling word
# ----
# check_word:  ahuisclos
# check_char_in_word:  ['s']
# ahuisclos : not repeat spelling word
# ----
# check_word:  argent
# argent : repeat spelling word
# ----
# check_word:  arbitrtor
# check_char_in_word:  ['r', 't']
# arbitrtor : not repeat spelling word
# ----
# check_word:  aspidistra
# check_char_in_word:  ['a', 's', 'i']
# aspidistra : not repeat spelling word
# ----
# check_word:  asphyxia
# check_char_in_word:  ['a']
# asphyxia : not repeat spelling word
# ----
# check_word:  acrolect
# check_char_in_word:  ['c']
# acrolect : not repeat spelling word
# ----
# check_word:  Assyria
# check_char_in_word:  ['s']
# Assyria : repeat spelling word
# ----
# check_word:  arcane
# check_char_in_word:  ['a']
# arcane : not repeat spelling word
# ----
# check_word:  astir
# astir : repeat spelling word
# ----
# check_word:  afterguard
# check_char_in_word:  ['a', 'r']
# afterguard : not repeat spelling word
# ----
# check_word:  assemblage
# check_char_in_word:  ['a', 's', 'e']
# assemblage : not repeat spelling word
# ----
# check_word:  airfight
# check_char_in_word:  ['i']
# airfight : not repeat spelling word
# ----
# check_word:  accredited
# check_char_in_word:  ['c', 'e', 'd']
# accredited : not repeat spelling word
# ----
# check_word:  alight
# alight : repeat spelling word
# ----
# check_word:  angidemocratic
# check_char_in_word:  ['a', 'i', 'c']
# angidemocratic : not repeat spelling word
# ----
# check_word:  archaism
# check_char_in_word:  ['a']
# archaism : not repeat spelling word
# ----
# check_word:  ascidium
# check_char_in_word:  ['i']
# ascidium : not repeat spelling word
# ----
# check_word:  activist
# check_char_in_word:  ['t', 'i']
# activist : not repeat spelling word
# ----
# check_word:  atmosphere
# check_char_in_word:  ['e']
# atmosphere : not repeat spelling word
# ----
# check_word:  abacus
# check_char_in_word:  ['a']
# abacus : not repeat spelling word
# ----
# check_word:  amazement
# check_char_in_word:  ['a', 'm', 'e']
# amazement : not repeat spelling word
# ----
# check_word:  ambush
# ambush : repeat spelling word
# ----
# check_word:  annexation
# check_char_in_word:  ['a', 'n']
# annexation : not repeat spelling word
# ----
# check_word:  alumnus
# check_char_in_word:  ['u']
# alumnus : not repeat spelling word
# ----
# check_word:  arcanum
# check_char_in_word:  ['a']
# arcanum : not repeat spelling word
# ----
# check_word:  ashtray
# check_char_in_word:  ['a']
# ashtray : not repeat spelling word
# ----
# check_word:  ametropia
# check_char_in_word:  ['a']
# ametropia : not repeat spelling word
# ----
# check_word:  aquamarine
# check_char_in_word:  ['a']
# aquamarine : not repeat spelling word
# ----
# check_word:  araucaria
# check_char_in_word:  ['a', 'r']
# araucaria : not repeat spelling word
# ----
# check_word:  angelology
# check_char_in_word:  ['g', 'l', 'o']
# angelology : not repeat spelling word
# ----
# check_word:  appendage
# check_char_in_word:  ['a', 'p', 'e']
# appendage : not repeat spelling word
# ----
# check_word:  amourette
# check_char_in_word:  ['e', 't']
# amourette : not repeat spelling word
# ----
# check_word:  archfool
# check_char_in_word:  ['o']
# archfool : repeat spelling word
# ----
# check_word:  anestrus
# check_char_in_word:  ['s']
# anestrus : not repeat spelling word
# ----
# check_word:  abhorrence
# check_char_in_word:  ['r', 'e']
# abhorrence : not repeat spelling word
# ----
# check_word:  admass
# check_char_in_word:  ['a', 's']
# admass : not repeat spelling word
# ----
# check_word:  aciform
# aciform : repeat spelling word
# ----
# check_word:  acoumeter
# check_char_in_word:  ['e']
# acoumeter : not repeat spelling word
# ----
# check_word:  ambergris
# check_char_in_word:  ['r']
# ambergris : not repeat spelling word
# ----
# check_word:  amelioration
# check_char_in_word:  ['a', 'i', 'o']
# amelioration : not repeat spelling word
# ----
# check_word:  assay
# check_char_in_word:  ['a', 's']
# assay : not repeat spelling word
# ----
# check_word:  atony
# atony : repeat spelling word
# ----
# check_word:  analphabetic
# check_char_in_word:  ['a']
# analphabetic : not repeat spelling word
# ----
# check_word:  animalization
# check_char_in_word:  ['a', 'n', 'i']
# animalization : not repeat spelling word
# ----
# check_word:  acreage
# check_char_in_word:  ['a', 'e']
# acreage : not repeat spelling word
# ----
# check_word:  almsman
# check_char_in_word:  ['a', 'm']
# almsman : not repeat spelling word
# ----
# check_word:  antimasque
# check_char_in_word:  ['a']
# antimasque : not repeat spelling word
# ----
# check_word:  advocator
# check_char_in_word:  ['a', 'o']
# advocator : not repeat spelling word
# ----
# check_word:  athleticism
# check_char_in_word:  ['t', 'i']
# athleticism : not repeat spelling word
# ----
# check_word:  alloverish
# check_char_in_word:  ['l']
# alloverish : repeat spelling word
# ----
# check_word:  apothegmatic
# check_char_in_word:  ['a', 't']
# apothegmatic : not repeat spelling word
# ----
# check_word:  abrogate
# check_char_in_word:  ['a']
# abrogate : not repeat spelling word
# ----
# check_word:  absonant
# check_char_in_word:  ['a', 'n']
# absonant : not repeat spelling word
# ----
# check_word:  acuity
# acuity : repeat spelling word
# ----
# check_word:  analyzation
# check_char_in_word:  ['a', 'n']
# analyzation : not repeat spelling word
# ----
# check_word:  amaryllis
# check_char_in_word:  ['a', 'l']
# amaryllis : not repeat spelling word
# ----
# check_word:  alible
# check_char_in_word:  ['l']
# alible : not repeat spelling word
# ----
# check_word:  accoucheuse
# check_char_in_word:  ['c', 'u', 'e']
# accoucheuse : not repeat spelling word
# ----
# check_word:  Amphibia
# check_char_in_word:  ['i']
# Amphibia : not repeat spelling word
# ----
# check_word:  angles
# angles : repeat spelling word
# ----
# check_word:  architectural
# check_char_in_word:  ['a', 'r', 'c', 't']
# architectural : not repeat spelling word
# ----
# check_word:  assuage
# check_char_in_word:  ['a', 's']
# assuage : not repeat spelling word
# ----
# check_word:  atrophy
# atrophy : repeat spelling word
# ----
# check_word:  atlatl
# check_char_in_word:  ['a', 't', 'l']
# atlatl : not repeat spelling word
# ----
# check_word:  anew
# anew : repeat spelling word
# ----
# check_word:  Archimedes
# check_char_in_word:  ['e']
# Archimedes : not repeat spelling word
# ----
# check_word:  activize
# check_char_in_word:  ['i']
# activize : not repeat spelling word
# ----
# check_word:  apiculturist
# check_char_in_word:  ['i', 'u', 't']
# apiculturist : not repeat spelling word
# ----
# check_word:  abreast
# check_char_in_word:  ['a']
# abreast : not repeat spelling word
# ----
# check_word:  ashiver
# ashiver : repeat spelling word
# ----
# check_word:  ancylostomiasis
# check_char_in_word:  ['a', 'o', 's', 'i']
# ancylostomiasis : not repeat spelling word
# ----
# check_word:  aft
# aft : repeat spelling word
# ----
# check_word:  altercation
# check_char_in_word:  ['a', 't']
# altercation : not repeat spelling word
# ----
# check_word:  altitude
# check_char_in_word:  ['t']
# altitude : not repeat spelling word
# ----
# check_word:  animadvert
# check_char_in_word:  ['a']
# animadvert : not repeat spelling word
# ----
# check_word:  abstersive
# check_char_in_word:  ['s', 'e']
# abstersive : not repeat spelling word
# ----
# check_word:  apolune
# apolune : repeat spelling word
# ----
# check_word:  actinoid
# check_char_in_word:  ['i']
# actinoid : not repeat spelling word
# ----
# check_word:  amplexicaul
# check_char_in_word:  ['a', 'l']
# amplexicaul : not repeat spelling word
# ----
# check_word:  Asher
# Asher : repeat spelling word
# ----
# check_word:  amadou
# check_char_in_word:  ['a']
# amadou : not repeat spelling word
# ----
# check_word:  Andrew
# Andrew : repeat spelling word
# ----
# check_word:  Alexandrian
# check_char_in_word:  ['a', 'n']
# Alexandrian : not repeat spelling word
# ----
# check_word:  animal
# check_char_in_word:  ['a']
# animal : not repeat spelling word
# ----
# check_word:  absent
# absent : repeat spelling word
# ----
# check_word:  alliteration
# check_char_in_word:  ['a', 'l', 'i', 't']
# alliteration : not repeat spelling word
# ----
# check_word:  aguish
# aguish : repeat spelling word
# ----
# check_word:  angulation
# check_char_in_word:  ['a', 'n']
# angulation : not repeat spelling word
# ----
# check_word:  aisle
# aisle : repeat spelling word
# ----
# check_word:  assignable
# check_char_in_word:  ['a', 's']
# assignable : not repeat spelling word
# ----
# check_word:  altimeter
# check_char_in_word:  ['t', 'e']
# altimeter : not repeat spelling word
# ----
# check_word:  agrostology
# check_char_in_word:  ['g', 'o']
# agrostology : not repeat spelling word
# ----
# check_word:  appui
# check_char_in_word:  ['p']
# appui : repeat spelling word
# ----
# check_word:  agreeably
# check_char_in_word:  ['a', 'e']
# agreeably : not repeat spelling word
# ----
# check_word:  archway
# check_char_in_word:  ['a']
# archway : not repeat spelling word
# ----
# check_word:  acinous
# acinous : repeat spelling word
# ----
# check_word:  alleviatory
# check_char_in_word:  ['a', 'l']
# alleviatory : not repeat spelling word
# ----
# check_word:  Argos
# Argos : repeat spelling word
# ----
# check_word:  affective
# check_char_in_word:  ['f', 'e']
# affective : not repeat spelling word
# ----
# check_word:  advantageous
# check_char_in_word:  ['a']
# advantageous : not repeat spelling word
# ----
# check_word:  ANVETS
# ANVETS : repeat spelling word
# ----
# check_word:  appraxia
# check_char_in_word:  ['a', 'p']
# appraxia : not repeat spelling word
# ----
# check_word:  accusatorial
# check_char_in_word:  ['a', 'c']
# accusatorial : not repeat spelling word
# ----
# check_word:  arcjet
# arcjet : repeat spelling word
# ----
# check_word:  astronautical
# check_char_in_word:  ['a', 't']
# astronautical : not repeat spelling word
# ----
# check_word:  augmented
# check_char_in_word:  ['e']
# augmented : not repeat spelling word
# ----
# check_word:  anthill
# check_char_in_word:  ['l']
# anthill : repeat spelling word
# ----
# check_word:  Alcmene
# check_char_in_word:  ['e']
# Alcmene : not repeat spelling word
# ----
# check_word:  alias
# check_char_in_word:  ['a']
# alias : not repeat spelling word
# ----
# check_word:  acromegalic
# check_char_in_word:  ['a', 'c']
# acromegalic : not repeat spelling word
# ----
# check_word:  auditing
# check_char_in_word:  ['i']
# auditing : not repeat spelling word
# ----
# check_word:  alliterate
# check_char_in_word:  ['a', 'l', 't', 'e']
# alliterate : not repeat spelling word
# ----
# check_word:  alphascope
# check_char_in_word:  ['a', 'p']
# alphascope : not repeat spelling word
# ----
# check_word:  altarpiece
# check_char_in_word:  ['a', 'e']
# altarpiece : not repeat spelling word
# ----
# check_word:  Amerasian
# check_char_in_word:  ['a']
# Amerasian : not repeat spelling word
# ----
# check_word:  allusion
# check_char_in_word:  ['l']
# allusion : repeat spelling word
# ----
# check_word:  Alma
# Alma : repeat spelling word
# ----
# check_word:  aerometry
# check_char_in_word:  ['e', 'r']
# aerometry : not repeat spelling word
# ----
# check_word:  amphibolic
# check_char_in_word:  ['i']
# amphibolic : not repeat spelling word
# ----
# check_word:  agricultural
# check_char_in_word:  ['a', 'r', 'u', 'l']
# agricultural : not repeat spelling word
# ----
# check_word:  ahermatype
# check_char_in_word:  ['a', 'e']
# ahermatype : not repeat spelling word
# ----
# check_word:  allotransplant
# check_char_in_word:  ['a', 'l', 't', 'n']
# allotransplant : not repeat spelling word
# ----
# check_word:  announcement
# check_char_in_word:  ['n', 'e']
# announcement : not repeat spelling word
# ----
# check_word:  apatite
# check_char_in_word:  ['a', 't']
# apatite : not repeat spelling word
# ----
# check_word:  absorbency
# check_char_in_word:  ['b']
# absorbency : not repeat spelling word
# ----
# check_word:  acronym
# acronym : repeat spelling word
# ----
# check_word:  album
# album : repeat spelling word
# ----
# check_word:  aback
# check_char_in_word:  ['a']
# aback : not repeat spelling word
# ----
# check_word:  algebraic
# check_char_in_word:  ['a']
# algebraic : not repeat spelling word
# ----
# check_word:  arborescent
# check_char_in_word:  ['r', 'e']
# arborescent : not repeat spelling word
# ----
# check_word:  armillary
# check_char_in_word:  ['a', 'r', 'l']
# armillary : not repeat spelling word
# ----
# check_word:  asafetida
# check_char_in_word:  ['a']
# asafetida : not repeat spelling word
# ----
# check_word:  ascorbate
# check_char_in_word:  ['a']
# ascorbate : not repeat spelling word
# ----
# check_word:  adopt
# adopt : repeat spelling word
# ----
# check_word:  aspirate
# check_char_in_word:  ['a']
# aspirate : not repeat spelling word
# ----
# check_word:  affirm
# check_char_in_word:  ['f']
# affirm : repeat spelling word
# ----
# check_word:  allfired
# check_char_in_word:  ['l']
# allfired : repeat spelling word
# ----
# check_word:  acetanilide
# check_char_in_word:  ['a', 'e', 'i']
# acetanilide : not repeat spelling word
# ----
# check_word:  aquaculture
# check_char_in_word:  ['a', 'u']
# aquaculture : not repeat spelling word
# ----
# check_word:  ahistoric
# check_char_in_word:  ['i']
# ahistoric : not repeat spelling word
# ----
# check_word:  arrive
# check_char_in_word:  ['r']
# arrive : repeat spelling word
# ----
# check_word:  aestivation
# check_char_in_word:  ['a', 't', 'i']
# aestivation : not repeat spelling word
# ----
# check_word:  aberrant
# check_char_in_word:  ['a', 'r']
# aberrant : not repeat spelling word
# ----
# check_word:  Adelaide
# check_char_in_word:  ['d', 'e']
# Adelaide : not repeat spelling word
# ----
# check_word:  abed
# abed : repeat spelling word
# ----
# check_word:  allemande
# check_char_in_word:  ['a', 'l', 'e']
# allemande : not repeat spelling word
# ----
# check_word:  anchorpeople
# check_char_in_word:  ['o', 'p', 'e']
# anchorpeople : not repeat spelling word
# ----
# check_word:  angelfish
# angelfish : repeat spelling word
# ----
# check_word:  antiracism
# check_char_in_word:  ['a', 'i']
# antiracism : not repeat spelling word
# ----
# check_word:  appellation
# check_char_in_word:  ['a', 'p', 'l']
# appellation : not repeat spelling word
# ----
# check_word:  appetizing
# check_char_in_word:  ['p', 'i']
# appetizing : not repeat spelling word
# ----
# check_word:  Arafat
# check_char_in_word:  ['a']
# Arafat : not repeat spelling word
# ----
# check_word:  armtwisting
# check_char_in_word:  ['t', 'i']
# armtwisting : not repeat spelling word
# ----
# check_word:  apperception
# check_char_in_word:  ['p', 'e']
# apperception : not repeat spelling word
# ----
# check_word:  afroamerican
# check_char_in_word:  ['a', 'r']
# afroamerican : not repeat spelling word
# ----
# check_word:  augustusaldosterone
# check_char_in_word:  ['a', 'u', 's', 't', 'o', 'e']
# augustusaldosterone : not repeat spelling word
# ----
# check_word:  Asclepius
# check_char_in_word:  ['s']
# Asclepius : not repeat spelling word
# ----
# check_word:  aff
# check_char_in_word:  ['f']
# aff : repeat spelling word
# ----
# check_word:  Aden
# Aden : repeat spelling word
# ----
# check_word:  amendable
# check_char_in_word:  ['a', 'e']
# amendable : not repeat spelling word
# ----
# check_word:  angry
# angry : repeat spelling word
# ----
# check_word:  aestivate
# check_char_in_word:  ['a', 'e', 't']
# aestivate : not repeat spelling word
# ----
# check_word:  adit
# adit : repeat spelling word
# ----
# check_word:  arithmetical
# check_char_in_word:  ['a', 'i', 't']
# arithmetical : not repeat spelling word
# ----
# check_word:  accent
# check_char_in_word:  ['c']
# accent : repeat spelling word
# ----
# check_word:  antenatal
# check_char_in_word:  ['a', 'n', 't']
# antenatal : not repeat spelling word
# ----
# check_word:  aeromechanics
# check_char_in_word:  ['a', 'e', 'c']
# aeromechanics : not repeat spelling word
# ----
# check_word:  asset
# check_char_in_word:  ['s']
# asset : repeat spelling word
# ----
# check_word:  agroecosystem
# check_char_in_word:  ['o', 'e', 's']
# agroecosystem : not repeat spelling word
# ----
# check_word:  agronomist
# check_char_in_word:  ['o']
# agronomist : not repeat spelling word
# ----
# check_word:  aroid
# aroid : repeat spelling word
# ----
# check_word:  antipathy
# check_char_in_word:  ['a', 't']
# antipathy : not repeat spelling word
# ----
# check_word:  arboriform
# check_char_in_word:  ['r', 'o']
# arboriform : not repeat spelling word
# ----
# check_word:  Athelstan
# check_char_in_word:  ['t']
# Athelstan : not repeat spelling word
# ----
# check_word:  adios
# adios : repeat spelling word
# ----
# check_word:  anamorphosis
# check_char_in_word:  ['a', 'o', 's']
# anamorphosis : not repeat spelling word
# ----
# check_word:  argo
# argo : repeat spelling word
# ----
# check_word:  athodyd
# check_char_in_word:  ['d']
# athodyd : not repeat spelling word
# ----
# check_word:  allout
# check_char_in_word:  ['l']
# allout : repeat spelling word
# ----
# check_word:  acetabulum
# check_char_in_word:  ['a', 'u']
# acetabulum : not repeat spelling word
# ----
# check_word:  anasarca
# check_char_in_word:  ['a']
# anasarca : not repeat spelling word
# ----
# check_word:  amoebiasis
# check_char_in_word:  ['a', 'i', 's']
# amoebiasis : not repeat spelling word
# ----
# check_word:  addle
# check_char_in_word:  ['d']
# addle : repeat spelling word
# ----
# check_word:  antennate
# check_char_in_word:  ['a', 'n', 't', 'e']
# antennate : not repeat spelling word
# ----
# check_word:  aquifer
# aquifer : repeat spelling word
# ----
# check_word:  audacity
# check_char_in_word:  ['a']
# audacity : not repeat spelling word
# ----
# check_word:  ariadne
# check_char_in_word:  ['a']
# ariadne : not repeat spelling word
# ----
# check_word:  amaranthine
# check_char_in_word:  ['a', 'n']
# amaranthine : not repeat spelling word
# ----
# check_word:  appaloosa
# check_char_in_word:  ['a', 'p', 'o']
# appaloosa : not repeat spelling word
# ----
# check_word:  agenize
# check_char_in_word:  ['e']
# agenize : not repeat spelling word
# ----
# check_word:  athanasy
# check_char_in_word:  ['a']
# athanasy : not repeat spelling word
# ----
# check_word:  alleviator
# check_char_in_word:  ['a', 'l']
# alleviator : not repeat spelling word
# ----
# check_word:  aerobiology
# check_char_in_word:  ['o']
# aerobiology : not repeat spelling word
# ----
# check_word:  acrostic
# check_char_in_word:  ['c']
# acrostic : not repeat spelling word
# ----
# check_word:  aghast
# check_char_in_word:  ['a']
# aghast : not repeat spelling word
# ----
# check_word:  anemic
# anemic : repeat spelling word
# ----
# check_word:  aeger
# check_char_in_word:  ['e']
# aeger : not repeat spelling word
# ----
# check_word:  anthropozoology
# check_char_in_word:  ['o']
# anthropozoology : not repeat spelling word
# ----
# check_word:  amphora
# check_char_in_word:  ['a']
# amphora : not repeat spelling word
# ----
# check_word:  anthropophagy
# check_char_in_word:  ['a', 'h', 'o', 'p']
# anthropophagy : not repeat spelling word
# ----
# check_word:  ancestral
# check_char_in_word:  ['a']
# ancestral : not repeat spelling word
# ----
# check_word:  action
# action : repeat spelling word
# ----
# check_word:  arithmetic
# check_char_in_word:  ['i', 't']
# arithmetic : not repeat spelling word
# ----
# check_word:  Anglomaniac
# check_char_in_word:  ['n', 'a']
# Anglomaniac : not repeat spelling word
# ----
# check_word:  audiotactile
# check_char_in_word:  ['a', 'i', 't']
# audiotactile : not repeat spelling word
# ----
# check_word:  ABC
# ABC : repeat spelling word
# ----
# check_word:  antimonopoly
# check_char_in_word:  ['n', 'o']
# antimonopoly : not repeat spelling word
# ----
# check_word:  applecart
# check_char_in_word:  ['a', 'p']
# applecart : not repeat spelling word
# ----
# check_word:  abiding
# check_char_in_word:  ['i']
# abiding : not repeat spelling word
# ----
# check_word:  anthracite
# check_char_in_word:  ['a', 't']
# anthracite : not repeat spelling word
# ----
# check_word:  airtight
# check_char_in_word:  ['i', 't']
# airtight : not repeat spelling word
# ----
# check_word:  afoot
# check_char_in_word:  ['o']
# afoot : repeat spelling word
# ----
# check_word:  ambulant
# check_char_in_word:  ['a']
# ambulant : not repeat spelling word
# ----
# check_word:  Ammon
# check_char_in_word:  ['m']
# Ammon : repeat spelling word
# ----
# check_word:  anilogarithm
# check_char_in_word:  ['a', 'i']
# anilogarithm : not repeat spelling word
# ----
# check_word:  Antonia
# check_char_in_word:  ['n']
# Antonia : not repeat spelling word
# ----
# check_word:  armlock
# armlock : repeat spelling word
# ----
# check_word:  acetometer
# check_char_in_word:  ['e', 't']
# acetometer : not repeat spelling word
# ----
# check_word:  aerotherapy
# check_char_in_word:  ['a', 'e', 'r']
# aerotherapy : not repeat spelling word
# ----
# check_word:  alms
# alms : repeat spelling word
# ----
# check_word:  anatomic
# check_char_in_word:  ['a']
# anatomic : not repeat spelling word
# ----
# check_word:  accordion
# check_char_in_word:  ['c', 'o']
# accordion : not repeat spelling word
# ----
# check_word:  aculeate
# check_char_in_word:  ['a', 'e']
# aculeate : not repeat spelling word
# ----
# check_word:  aphicide
# check_char_in_word:  ['i']
# aphicide : not repeat spelling word
# ----
# check_word:  aerodynamics
# check_char_in_word:  ['a']
# aerodynamics : not repeat spelling word
# ----
# check_word:  anadromous
# check_char_in_word:  ['a', 'o']
# anadromous : not repeat spelling word
# ----
# check_word:  abovedeck
# check_char_in_word:  ['e']
# abovedeck : not repeat spelling word
# ----
# check_word:  actively
# actively : repeat spelling word
# ----
# check_word:  Anglophilia
# check_char_in_word:  ['l', 'i']
# Anglophilia : not repeat spelling word
# ----
# check_word:  abasia
# check_char_in_word:  ['a']
# abasia : not repeat spelling word
# ----
# check_word:  Apache
# Apache : repeat spelling word
# ----
# check_word:  albino
# albino : repeat spelling word
# ----
# check_word:  acquaint
# check_char_in_word:  ['a']
# acquaint : not repeat spelling word
# ----
# check_word:  arbalest
# check_char_in_word:  ['a']
# arbalest : not repeat spelling word
# ----
# check_word:  aubade
# check_char_in_word:  ['a']
# aubade : not repeat spelling word
# ----
# check_word:  apostolic
# check_char_in_word:  ['o']
# apostolic : not repeat spelling word
# ----
# check_word:  adulterator
# check_char_in_word:  ['a', 't', 'r']
# adulterator : not repeat spelling word
# ----
# check_word:  aparthetic
# check_char_in_word:  ['a', 't']
# aparthetic : not repeat spelling word
# ----
# check_word:  arris
# check_char_in_word:  ['r']
# arris : repeat spelling word
# ----
# check_word:  audiology
# check_char_in_word:  ['o']
# audiology : not repeat spelling word
# ----
# check_word:  assiduity
# check_char_in_word:  ['s', 'i']
# assiduity : not repeat spelling word
# ----
# check_word:  anticathode
# check_char_in_word:  ['a', 't']
# anticathode : not repeat spelling word
# ----
# check_word:  anhinga
# check_char_in_word:  ['a', 'n']
# anhinga : not repeat spelling word
# ----
# check_word:  antibacterial
# check_char_in_word:  ['a', 't', 'i']
# antibacterial : not repeat spelling word
# ----
# check_word:  afteryears
# check_char_in_word:  ['a', 'e', 'r']
# afteryears : not repeat spelling word
# ----
# check_word:  airstream
# check_char_in_word:  ['a', 'r']
# airstream : not repeat spelling word
# ----
# check_word:  aggregate
# check_char_in_word:  ['a', 'g', 'e']
# aggregate : not repeat spelling word
# ----
# check_word:  adjudgement
# check_char_in_word:  ['d', 'e']
# adjudgement : not repeat spelling word
# ----
# check_word:  acidophilus
# check_char_in_word:  ['i']
# acidophilus : not repeat spelling word
# ----
# check_word:  allograph
# check_char_in_word:  ['a', 'l']
# allograph : not repeat spelling word
# ----
# check_word:  anacoluthon
# check_char_in_word:  ['a', 'n', 'o']
# anacoluthon : not repeat spelling word
# ----
# check_word:  anthropomorphize
# check_char_in_word:  ['h', 'r', 'o', 'p']
# anthropomorphize : not repeat spelling word
# ----
# check_word:  aground
# aground : repeat spelling word
# ----
# check_word:  agriculture
# check_char_in_word:  ['r', 'u']
# agriculture : not repeat spelling word
# ----
# check_word:  allupweight
# check_char_in_word:  ['l']
# allupweight : repeat spelling word
# ----
# check_word:  ascomycete
# check_char_in_word:  ['c', 'e']
# ascomycete : not repeat spelling word
# ----
# check_word:  analogical
# check_char_in_word:  ['a', 'l']
# analogical : not repeat spelling word
# ----
# check_word:  aerography
# check_char_in_word:  ['a', 'r']
# aerography : not repeat spelling word
# ----
# check_word:  asiatic
# check_char_in_word:  ['a', 'i']
# asiatic : not repeat spelling word
# ----
# check_word:  aggrandize
# check_char_in_word:  ['a', 'g']
# aggrandize : not repeat spelling word
# ----
# check_word:  allround
# check_char_in_word:  ['l']
# allround : repeat spelling word
# ----
# check_word:  as
# as : repeat spelling word
# ----
# check_word:  absorption
# check_char_in_word:  ['o']
# absorption : not repeat spelling word
# ----
# check_word:  alewife
# check_char_in_word:  ['e']
# alewife : not repeat spelling word
# ----
# check_word:  aestheticism
# check_char_in_word:  ['e', 's', 't', 'i']
# aestheticism : not repeat spelling word
# ----
# check_word:  amphi
# amphi : repeat spelling word
# ----
# check_word:  accessorize
# check_char_in_word:  ['c', 'e', 's']
# accessorize : not repeat spelling word
# ----
# check_word:  absurdity
# absurdity : repeat spelling word
# ----
# check_word:  aesthete
# check_char_in_word:  ['e', 't']
# aesthete : not repeat spelling word
# ----
# check_word:  adenoid
# check_char_in_word:  ['d']
# adenoid : not repeat spelling word
# ----
# check_word:  acronymize
# acronymize : repeat spelling word
# ----
# check_word:  actinozoan
# check_char_in_word:  ['a', 'n', 'o']
# actinozoan : not repeat spelling word
# ----
# check_word:  alcoholysis
# check_char_in_word:  ['l', 'o', 's']
# alcoholysis : not repeat spelling word
# ----
# check_word:  amok
# amok : repeat spelling word
# ----
# check_word:  aphrodisiac
# check_char_in_word:  ['a', 'i']
# aphrodisiac : not repeat spelling word
# ----
# check_word:  abusive
# abusive : repeat spelling word
# ----
# check_word:  admix
# admix : repeat spelling word
# ----
# check_word:  aerobatic
# check_char_in_word:  ['a']
# aerobatic : not repeat spelling word
# ----
# check_word:  aspergillum
# check_char_in_word:  ['l']
# aspergillum : repeat spelling word
# ----
# check_word:  anyone
# check_char_in_word:  ['n']
# anyone : not repeat spelling word
# ----
# check_word:  aton
# aton : repeat spelling word
# ----
# check_word:  antiseptic
# check_char_in_word:  ['t', 'i']
# antiseptic : not repeat spelling word
# ----
# check_word:  abyssal
# check_char_in_word:  ['a', 's']
# abyssal : not repeat spelling word
# ----
# check_word:  afterthought
# check_char_in_word:  ['t', 'h']
# afterthought : not repeat spelling word
# ----
# check_word:  accomplishment
# check_char_in_word:  ['c', 'm']
# accomplishment : not repeat spelling word
# ----
# check_word:  acute
# acute : repeat spelling word
# ----
# check_word:  alienable
# check_char_in_word:  ['a', 'l', 'e']
# alienable : not repeat spelling word
# ----
# check_word:  antimissile
# check_char_in_word:  ['i', 's']
# antimissile : not repeat spelling word
# ----
# check_word:  argentite
# check_char_in_word:  ['e', 't']
# argentite : not repeat spelling word
# ----
# check_word:  arsenical
# check_char_in_word:  ['a']
# arsenical : not repeat spelling word
# ----
# check_word:  aertex
# check_char_in_word:  ['e']
# aertex : not repeat spelling word
# ----
# check_word:  agronomy
# check_char_in_word:  ['o']
# agronomy : not repeat spelling word
# ----
# check_word:  ambages
# check_char_in_word:  ['a']
# ambages : not repeat spelling word
# ----
# check_word:  Adenauer
# check_char_in_word:  ['e']
# Adenauer : not repeat spelling word
# ----
# check_word:  arched
# arched : repeat spelling word
# ----
# check_word:  alimentative
# check_char_in_word:  ['a', 'i', 'e', 't']
# alimentative : not repeat spelling word
# ----
# check_word:  ago
# ago : repeat spelling word
# ----
# check_word:  aciculate
# check_char_in_word:  ['a', 'c']
# aciculate : not repeat spelling word
# ----
# check_word:  alanine
# check_char_in_word:  ['a', 'n']
# alanine : not repeat spelling word
# ----
# check_word:  alimental
# check_char_in_word:  ['a', 'l']
# alimental : not repeat spelling word
# ----
# check_word:  abstruse
# check_char_in_word:  ['s']
# abstruse : not repeat spelling word
# ----
# check_word:  Afrobeat
# Afrobeat : repeat spelling word
# ----
# check_word:  aesthetician
# check_char_in_word:  ['a', 'e', 't', 'i']
# aesthetician : not repeat spelling word
# ----
# check_word:  assimilator
# check_char_in_word:  ['a', 's', 'i']
# assimilator : not repeat spelling word
# ----
# check_word:  arbitral
# check_char_in_word:  ['a', 'r']
# arbitral : not repeat spelling word
# ----
# check_word:  allergenic
# check_char_in_word:  ['l', 'e']
# allergenic : not repeat spelling word
# ----
# check_word:  affirmative
# check_char_in_word:  ['a', 'f', 'i']
# affirmative : not repeat spelling word
# ----
# check_word:  against
# check_char_in_word:  ['a']
# ...
# check_char_in_word:  ['a', 'e']
# amenable : not repeat spelling word
# ----
# check_word:  aspartokinase
# check_char_in_word:  ['a', 's']
# aspartokinase : not repeat spelling word
# ----
# check_word:  attested
# check_char_in_word:  ['t', 'e']
# attested : not repeat spelling word
# ----
# check_word:  agribaron
# check_char_in_word:  ['a', 'r']
# agribaron : not repeat spelling word
# ----
# check_word:  Aterian
# Aterian : repeat spelling word
# ----
# check_word:  abomasum
# check_char_in_word:  ['a', 'm']
# abomasum : not repeat spelling word
# ----
# check_word:  artrological
# check_char_in_word:  ['a', 'r', 'o', 'l']
# artrological : not repeat spelling word
# ----
# check_word:  adiabatic
# check_char_in_word:  ['a', 'i']
# adiabatic : not repeat spelling word
# ----
# check_word:  accordingly
# check_char_in_word:  ['c']
# accordingly : repeat spelling word
# ----
# check_word:  allophane
# check_char_in_word:  ['a', 'l']
# allophane : not repeat spelling word
# ----
# check_word:  alone
# alone : repeat spelling word
# ----
# check_word:  Antoon
# check_char_in_word:  ['n', 'o']
# Antoon : not repeat spelling word
# ----
# check_word:  arithmometer
# check_char_in_word:  ['r', 't', 'm', 'e']
# arithmometer : not repeat spelling word
# ----
# check_word:  accessorily
# check_char_in_word:  ['c', 's']
# accessorily : repeat spelling word
# ----
# check_word:  ataxia
# check_char_in_word:  ['a']
# ataxia : not repeat spelling word
# ----
# check_word:  absorbed
# check_char_in_word:  ['b']
# absorbed : not repeat spelling word
# ----
# check_word:  amnioscopy
# check_char_in_word:  ['o']
# amnioscopy : not repeat spelling word
# ----
# check_word:  aditorial
# check_char_in_word:  ['a', 'i']
# aditorial : not repeat spelling word
# ----
# check_word:  agroindustrial
# check_char_in_word:  ['a', 'r', 'i']
# agroindustrial : not repeat spelling word
# ----
# check_word:  Alpine
# Alpine : repeat spelling word
# ----
# check_word:  anchoret
# anchoret : repeat spelling word
# ----
# check_word:  approved
# check_char_in_word:  ['p']
# approved : repeat spelling word
# ----
# check_word:  acariasis
# check_char_in_word:  ['a', 'i', 's']
# acariasis : not repeat spelling word
# ----
# check_word:  acetylene
# check_char_in_word:  ['e']
# acetylene : not repeat spelling word
# ----
# check_word:  Annelida
# check_char_in_word:  ['n']
# Annelida : repeat spelling word
# ----
# check_word:  Algeria
# Algeria : repeat spelling word
# ----
# check_word:  ambivalence
# check_char_in_word:  ['a', 'e']
# ambivalence : not repeat spelling word
# ----
# check_word:  ambulation
# check_char_in_word:  ['a']
# ambulation : not repeat spelling word
# ----
# check_word:  afore
# afore : repeat spelling word
# ----
# check_word:  acro
# acro : repeat spelling word
# ----
# check_word:  alluvion
# check_char_in_word:  ['l']
# alluvion : repeat spelling word
# ----
# check_word:  assessable
# check_char_in_word:  ['a', 's', 'e']
# assessable : not repeat spelling word
# ----
# check_word:  alphametic
# check_char_in_word:  ['a']
# alphametic : not repeat spelling word
# ----
# check_word:  Afghanistanism
# check_char_in_word:  ['a', 'n', 'i', 's']
# Afghanistanism : not repeat spelling word
# ----
# check_word:  attributive
# check_char_in_word:  ['t', 'i']
# attributive : not repeat spelling word
# ----
# check_word:  apheliotropic
# check_char_in_word:  ['p', 'i', 'o']
# apheliotropic : not repeat spelling word
# ----
# check_word:  amphitheatric
# check_char_in_word:  ['a', 'h', 'i', 't']
# amphitheatric : not repeat spelling word
# ----
# check_word:  algerian
# check_char_in_word:  ['a']
# algerian : not repeat spelling word
# ----
# check_word:  Algiers
# Algiers : repeat spelling word
# ----
# check_word:  astrocyte
# check_char_in_word:  ['t']
# astrocyte : not repeat spelling word
# ----
# check_word:  adherence
# check_char_in_word:  ['e']
# adherence : not repeat spelling word
# ----
# check_word:  armorer
# check_char_in_word:  ['r']
# armorer : not repeat spelling word
# ----
# check_word:  allimportant
# check_char_in_word:  ['a', 'l', 't']
# allimportant : not repeat spelling word
# ----
# check_word:  Anglicization
# check_char_in_word:  ['n', 'i']
# Anglicization : not repeat spelling word
# ----
# check_word:  animatograph
# check_char_in_word:  ['a']
# animatograph : not repeat spelling word
# ----
# check_word:  assemblyman
# check_char_in_word:  ['a', 's', 'm']
# assemblyman : not repeat spelling word
# ----
# check_word:  abnormal
# check_char_in_word:  ['a']
# abnormal : not repeat spelling word
# ----
# check_word:  abuttal
# check_char_in_word:  ['a', 't']
# abuttal : not repeat spelling word
# ----
# check_word:  arch(a)elogical
# check_char_in_word:  ['a', 'c', 'l']
# arch(a)elogical : not repeat spelling word
# ----
# check_word:  antefix
# antefix : repeat spelling word
# ----
# check_word:  accede
# check_char_in_word:  ['c', 'e']
# accede : not repeat spelling word
# ----
# check_word:  aquavitae
# check_char_in_word:  ['a']
# aquavitae : not repeat spelling word
# ----
# check_word:  antisubversive
# check_char_in_word:  ['i', 's', 'v', 'e']
# antisubversive : not repeat spelling word
# ----
# check_word:  agley
# agley : repeat spelling word
# ----
# check_word:  apterous
# apterous : repeat spelling word
# ----
# check_word:  accredit
# check_char_in_word:  ['c']
# accredit : repeat spelling word
# ----
# check_word:  adverb
# adverb : repeat spelling word
# ----
# check_word:  aerophone
# check_char_in_word:  ['e', 'o']
# aerophone : not repeat spelling word
# ----
# check_word:  appropriative
# check_char_in_word:  ['a', 'p', 'r', 'i']
# appropriative : not repeat spelling word
# ----
# check_word:  Academy
# Academy : repeat spelling word
# ----
# check_word:  Arkwight
# Arkwight : repeat spelling word
# ----
# check_word:  anthropogenesis
# check_char_in_word:  ['n', 'o', 'e', 's']
# anthropogenesis : not repeat spelling word
# ----
# check_word:  ablation
# check_char_in_word:  ['a']
# ablation : not repeat spelling word
# ----
# check_word:  Alberta
# Alberta : repeat spelling word
# ----
# check_word:  asthma
# check_char_in_word:  ['a']
# asthma : not repeat spelling word
# ----
# check_word:  almanac
# check_char_in_word:  ['a']
# almanac : not repeat spelling word
# ----
# check_word:  anticodon
# check_char_in_word:  ['n', 'o']
# anticodon : not repeat spelling word
# ----
# check_word:  anaphase
# check_char_in_word:  ['a']
# anaphase : not repeat spelling word
# ----
# check_word:  adsorbent
# adsorbent : repeat spelling word
# ----
# check_word:  Angostura
# Angostura : repeat spelling word
# ----
# check_word:  Aswan
# Aswan : repeat spelling word
# ----
# check_word:  astromerty
# check_char_in_word:  ['t', 'r']
# astromerty : not repeat spelling word
# ----
# check_word:  afterclap
# check_char_in_word:  ['a']
# afterclap : not repeat spelling word
# ----
# check_word:  arbitrable
# check_char_in_word:  ['a', 'r', 'b']
# arbitrable : not repeat spelling word
# ----
# check_word:  aroint
# aroint : repeat spelling word
# ----
# check_word:  amyloid
# amyloid : repeat spelling word
# ----
# check_word:  abwatt
# check_char_in_word:  ['a', 't']
# abwatt : not repeat spelling word
# ----
# check_word:  antihelix
# check_char_in_word:  ['i']
# antihelix : not repeat spelling word
# ----
# check_word:  Arminian
# check_char_in_word:  ['i', 'n']
# Arminian : not repeat spelling word
# ----
# check_word:  ampere
# check_char_in_word:  ['e']
# ampere : not repeat spelling word
# ----
# check_word:  Aufklarung
# check_char_in_word:  ['u']
# Aufklarung : not repeat spelling word
# ----
# check_word:  anemoscope
# check_char_in_word:  ['e', 'o']
# anemoscope : not repeat spelling word
# ----
# check_word:  abstractly
# check_char_in_word:  ['a', 't']
# abstractly : not repeat spelling word
# ----
# check_word:  archipelago
# check_char_in_word:  ['a']
# archipelago : not repeat spelling word
# ----
# check_word:  aim
# aim : repeat spelling word
# ----
# check_word:  alienator
# check_char_in_word:  ['a']
# alienator : not repeat spelling word
# ----
# check_word:  antic
# antic : repeat spelling word
# ----
# check_word:  antiageing
# check_char_in_word:  ['a', 'n', 'i', 'g']
# antiageing : not repeat spelling word
# ----
# check_word:  appulse
# check_char_in_word:  ['p']
# appulse : repeat spelling word
# ----
# check_word:  accurately
# check_char_in_word:  ['a', 'c']
# accurately : not repeat spelling word
# ----
# check_word:  alevin
# alevin : repeat spelling word
# ----
# check_word:  asicism
# check_char_in_word:  ['s', 'i']
# asicism : not repeat spelling word
# ----
# check_word:  amperehour
# check_char_in_word:  ['e', 'r']
# amperehour : not repeat spelling word
# ----
# check_word:  apaneid
# check_char_in_word:  ['a']
# apaneid : not repeat spelling word
# ----
# check_word:  Anthea
# Anthea : repeat spelling word
# ----
# check_word:  anteflexion
# check_char_in_word:  ['n', 'e']
# anteflexion : not repeat spelling word
# ----
# check_word:  abalone
# check_char_in_word:  ['a']
# abalone : not repeat spelling word
# ----
# check_word:  agora
# check_char_in_word:  ['a']
# agora : not repeat spelling word
# ----
# check_word:  archness
# check_char_in_word:  ['s']
# archness : repeat spelling word
# ----
# check_word:  aphesis
# check_char_in_word:  ['s']
# aphesis : not repeat spelling word
# ----
# check_word:  acquisition
# check_char_in_word:  ['i']
# acquisition : not repeat spelling word
# ----
# check_word:  Altamira
# check_char_in_word:  ['a']
# Altamira : not repeat spelling word
# ----
# check_word:  arpeggio
# check_char_in_word:  ['g']
# arpeggio : repeat spelling word
# ----
# check_word:  artery
# check_char_in_word:  ['r']
# artery : not repeat spelling word
# ----
# check_word:  antediluvian
# check_char_in_word:  ['a', 'n', 'i']
# antediluvian : not repeat spelling word
# ----
# check_word:  Alan
# Alan : repeat spelling word
# ----
# check_word:  Ardennes
# check_char_in_word:  ['e', 'n']
# Ardennes : not repeat spelling word
# ----
# check_word:  appellate
# check_char_in_word:  ['a', 'p', 'e', 'l']
# appellate : not repeat spelling word
# ----
# check_word:  astrosphere
# check_char_in_word:  ['s', 'r', 'e']
# astrosphere : not repeat spelling word
# ----
# check_word:  anguish
# anguish : repeat spelling word
# ----
# check_word:  adventurous
# check_char_in_word:  ['u']
# adventurous : not repeat spelling word
# ----
# check_word:  antiMarketeer
# check_char_in_word:  ['a', 't', 'r', 'e']
# antiMarketeer : not repeat spelling word
# ----
# check_word:  alleviate
# check_char_in_word:  ['a', 'l', 'e']
# alleviate : not repeat spelling word
# ----
# check_word:  afterward
# check_char_in_word:  ['a', 'r']
# afterward : not repeat spelling word
# ----
# check_word:  allway
# check_char_in_word:  ['a', 'l']
# allway : not repeat spelling word
# ----
# check_word:  account
# check_char_in_word:  ['c']
# account : repeat spelling word
# ----
# check_word:  aggregative
# check_char_in_word:  ['a', 'g', 'e']
# aggregative : not repeat spelling word
# ----
# check_word:  amicability
# check_char_in_word:  ['a', 'i']
# amicability : not repeat spelling word
# ----
# check_word:  appertain
# check_char_in_word:  ['a', 'p']
# appertain : not repeat spelling word
# ----
# check_word:  anticonvulsant
# check_char_in_word:  ['a', 'n', 't']
# anticonvulsant : not repeat spelling word
# ----
# check_word:  ARM
# ARM : repeat spelling word
# ----
# check_word:  afoul
# afoul : repeat spelling word
# ----
# check_word:  acock
# check_char_in_word:  ['c']
# acock : not repeat spelling word
# ----
# check_word:  anuresis
# check_char_in_word:  ['s']
# anuresis : not repeat spelling word
# ----
# check_word:  absentminded
# check_char_in_word:  ['e', 'n', 'd']
# absentminded : not repeat spelling word
# ----
# check_word:  adulterine
# check_char_in_word:  ['e']
# adulterine : not repeat spelling word
# ----
# check_word:  absorptive
# absorptive : repeat spelling word
# ----
# check_word:  Alps
# Alps : repeat spelling word
# ----
# check_word:  anteprandial
# check_char_in_word:  ['a', 'n']
# anteprandial : not repeat spelling word
# ----
# check_word:  accommodation
# check_char_in_word:  ['a', 'c', 'o', 'm']
# accommodation : not repeat spelling word
# ----
# check_word:  actuality
# check_char_in_word:  ['a', 't']
# actuality : not repeat spelling word
# ----
# check_word:  adjutant
# check_char_in_word:  ['a', 't']
# adjutant : not repeat spelling word
# ----
# check_word:  aged
# aged : repeat spelling word
# ----
# check_word:  Amytal
# Amytal : repeat spelling word
# ----
# check_word:  atwitter
# check_char_in_word:  ['t']
# atwitter : not repeat spelling word
# ----
# check_word:  ancienregime
# check_char_in_word:  ['n', 'i', 'e']
# ancienregime : not repeat spelling word
# ----
# check_word:  arrhythmia
# check_char_in_word:  ['a', 'r', 'h']
# arrhythmia : not repeat spelling word
# ----
# check_word:  Audrey
# Audrey : repeat spelling word
# ----
# check_word:  agegroup
# check_char_in_word:  ['g']
# agegroup : not repeat spelling word
# ----
# check_word:  arrivism
# check_char_in_word:  ['r', 'i']
# arrivism : not repeat spelling word
# ----
# check_word:  Ahead
# Ahead : repeat spelling word
# ----
# check_word:  Army
# Army : repeat spelling word
# ----
# check_word:  asynchronism
# check_char_in_word:  ['s', 'n']
# asynchronism : not repeat spelling word
# ----
# check_word:  acious
# acious : repeat spelling word
# ----
# check_word:  Amboina
# Amboina : repeat spelling word
# ----
# check_word:  affettuoso
# check_char_in_word:  ['f', 't', 'o']
# affettuoso : not repeat spelling word
# ----
# check_word:  apparatus
# check_char_in_word:  ['a', 'p']
# apparatus : not repeat spelling word
# ----
# check_word:  adynamic
# check_char_in_word:  ['a']
# adynamic : not repeat spelling word
# ----
# check_word:  Aeolian
# Aeolian : repeat spelling word
# ----
# check_word:  anchovy
# anchovy : repeat spelling word
# ----
# check_word:  aficionado
# check_char_in_word:  ['a', 'i', 'o']
# aficionado : not repeat spelling word
# ----
# check_word:  amidship
# check_char_in_word:  ['i']
# amidship : not repeat spelling word
# ----
# check_word:  ancestress
# check_char_in_word:  ['e', 's']
# ancestress : not repeat spelling word
# ----
# check_word:  aioli
# check_char_in_word:  ['i']
# aioli : not repeat spelling word
# ----
# check_word:  assembled
# check_char_in_word:  ['s', 'e']
# assembled : not repeat spelling word
# ----
# check_word:  accreditation
# check_char_in_word:  ['a', 'c', 'i', 't']
# accreditation : not repeat spelling word
# ----
# check_word:  Americanization
# check_char_in_word:  ['i', 'a', 'n']
# Americanization : not repeat spelling word
# ----
# check_word:  academy
# check_char_in_word:  ['a']
# academy : not repeat spelling word
# ----
# check_word:  acrophobe
# check_char_in_word:  ['o']
# acrophobe : not repeat spelling word
# ----
# check_word:  acme
# acme : repeat spelling word
# ----
# check_word:  allot
# check_char_in_word:  ['l']
# allot : repeat spelling word
# ----
# check_word:  aquaphobia
# check_char_in_word:  ['a']
# aquaphobia : not repeat spelling word
# ----
# check_word:  Athena
# Athena : repeat spelling word
# ----
# check_word:  attenuant
# check_char_in_word:  ['a', 't', 'n']
# attenuant : not repeat spelling word
# ----
# check_word:  asylum
# asylum : repeat spelling word
# ----
# check_word:  antarctic
# check_char_in_word:  ['a', 't', 'c']
# antarctic : not repeat spelling word
# ----
# check_word:  armadillo
# check_char_in_word:  ['a', 'l']
# armadillo : not repeat spelling word
# ----
# check_word:  absently
# absently : repeat spelling word
# ----
# check_word:  apeman
# check_char_in_word:  ['a']
# apeman : not repeat spelling word
# ----
# check_word:  audiometer
# check_char_in_word:  ['e']
# audiometer : not repeat spelling word
# ----
# check_word:  aerify
# aerify : repeat spelling word
# ----
# check_word:  Asperges
# check_char_in_word:  ['s', 'e']
# Asperges : not repeat spelling word
# ----
# check_word:  analogous
# check_char_in_word:  ['a', 'o']
# analogous : not repeat spelling word
# ----
# check_word:  aloft
# aloft : repeat spelling word
# ----
# check_word:  abruption
# abruption : repeat spelling word
# ----
# check_word:  arithmetician
# check_char_in_word:  ['a', 'i', 't']
# arithmetician : not repeat spelling word
# ----
# check_word:  apish
# apish : repeat spelling word
# ----
# check_word:  ammonite
# check_char_in_word:  ['m']
# ammonite : repeat spelling word
# ----
# check_word:  aspectual
# check_char_in_word:  ['a']
# aspectual : not repeat spelling word
# ----
# check_word:  aldrin
# aldrin : repeat spelling word
# ----
# check_word:  airplane
# check_char_in_word:  ['a']
# airplane : not repeat spelling word
# ----
# check_word:  ambler
# ambler : repeat spelling word
# ----
# check_word:  attune
# check_char_in_word:  ['t']
# attune : repeat spelling word
# ----
# check_word:  antiskyjacking
# check_char_in_word:  ['a', 'n', 'i', 'k']
# antiskyjacking : not repeat spelling word
# ----
# check_word:  abort
# abort : repeat spelling word
# ----
# check_word:  aquatel
# check_char_in_word:  ['a']
# aquatel : not repeat spelling word
# 2076

# %% [markdown]
# # 4.
#
# - 6은 1,2,3,6의 4개의 약수를 가지고 8은 1,2,4,8의 4개의 약수를 가지며,10은 1,2,5,10의 4개의 약수를 가진다
#
#
#
# - 따라서 5이상 10이하의 범위에서 4개의 약수를 가지는 수는 6,8,10의 3개이다.
#
#
# - 이렇게 약수의 개수 k와 수의 범위a,b(0<=a,b<=100000)가 주어질 때 조건을 만족하는 수와 개수를 출력하는 프로그램을 작성하라

# %%
k = int(input('약수의 개수: '))
a = int(input('시작 범위: '))
b = int(input('끝 범위: '))
answer_numbers = []

# 약수의 개수가 홀수라는건 제곱수
if k%2 == 1:

    # a에서 b까지 정수가 돌아갑니다.
    for num_a in range(a,b+1):
        
        #k와 비교할 count
        count_a=0
        #print('----------')
        #print('Number: ',num_a)
        
        #num을 1부터 num까지의 숫자로 나눠보자 
        for i in range(1,num_a+1):
            if num_a%i == 0:
                count_a += 1
        
        if count_a == k:
            answer_numbers.append(num_a)
            
# 약수의 개수가 짝수            
else:
    
    # a에서 b까지 정수가 돌아갑니다.
    for num_b in range(a,b+1):
        
        #k와 비교할 count
        count_b = 0
        #print('---------')
        #print('Number: ',num_b)
        
        #num을 1부터 num까지의 숫자로 나눠보자
        for j in range(1,num_b+1):
            if num_b%j == 0:
                count_b +=1
            
            if count_b ==k:
                answer_numbers.append(num_b)
            
print(answer_numbers)            
print(len(answer_numbers),' 개 입니다.')
# Out:
# 약수의 개수: 4
# 시작 범위: 5
# 끝 범위: 10
# [6, 8, 10]
# 3  개 입니다.

# %% [markdown]
# # 5.
#
# - B(2<=B<=)를 입력했을때 진수대칭변환을 찾고 싶다.
#
# - 진수대칭변환일아 1부터 300까지의 수 중에서 그 제곱을 B진수로 표현했을 때,
#
# - 좌우대칭이 되는 경우를 말한다.
#
# - B 입력시 진수대칭변환 출력 후 개수를 구하는 프로그램을 작성하라.

# %%
def convert(n, B):
    T = "0123456789"
    quotient, remainder = divmod(n, B)
    
    # 몫이 0이면  
    if quotient == 0:
        return T[remainder]
    else:
        return convert(quotient, B) + T[remainder]

# %%
def symmetry(a):
    lenn = len(a)
    
    #변환한 수가 홀수
    if lenn%2 == 1:
        idx=int(lenn/2)
        forward = a[:idx]
        backward = a[idx+1:]
        backward = backward[::-1]
        return forward == backward
    
    #변환한 수가 짝수
    else:
        idx = int(lenn/2)
        forward = a[:idx]
        backward = a[idx:]
        backward = backward[::-1]
        return forward == backward

# %%
B = int(input('B진수로 변환: '))
count = 0
for i in range(1,301):
    square=i*i
    check=convert(square,B)
    
    if symmetry(check):
        count+=1
        print(i,'-> 제곱: ', square,'-> 대칭변환:  ', check)
print(count,'개의 진수대칭변환이 있습니다.')
# Out:
# B진수로 변환: 3
# 1 -> 제곱:  1 -> 대칭변환:   1
# 2 -> 제곱:  4 -> 대칭변환:   11
# 4 -> 제곱:  16 -> 대칭변환:   121
# 10 -> 제곱:  100 -> 대칭변환:   10201
# 11 -> 제곱:  121 -> 대칭변환:   11111
# 20 -> 제곱:  400 -> 대칭변환:   112211
# 22 -> 제곱:  484 -> 대칭변환:   122221
# 28 -> 제곱:  784 -> 대칭변환:   1002001
# 34 -> 제곱:  1156 -> 대칭변환:   1120211
# 56 -> 제곱:  3136 -> 대칭변환:   11022011
# 82 -> 제곱:  6724 -> 대칭변환:   100020001
# 89 -> 제곱:  7921 -> 대칭변환:   101212101
# 113 -> 제곱:  12769 -> 대칭변환:   122111221
# 154 -> 제곱:  23716 -> 대칭변환:   1012112101
# 164 -> 제곱:  26896 -> 대칭변환:   1100220011
# 244 -> 제곱:  59536 -> 대칭변환:   10000200001
# 262 -> 제곱:  68644 -> 대칭변환:   10111011101
# 17 개의 진수대칭변환이 있습니다.

# %%
print(divmod(1,2))
# Out:
# (0, 1)

# %%
liii ='1001'

# %%
cc=liii[:int(len(liii)/2)]
cc
# Out:
# '10'

# %%
bb=liii[int(len(liii)/2):]
bb=bb[::-1]
bb
# Out:
# '10'

# %%
cc == bb
# Out:
# True

# %%
cc
# Out:
# [1, 3]

# %%
bb
# Out:
# [3, 1]
